# %%
from TravelSalesman import * 

driver_ai = TaxiDriverAI()
driver_ai.generate_random_points(num_points = 100)
driver_ai.static_plot()
# Out:
# Random points map saved as random_points_map.html.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d0254b1f15fe5b7eefedbca47862605 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d0254b1f15fe5b7eefedbca47862605&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d0254b1f15fe5b7eefedbca47862605 = L.map(
#                 &quot;map_6d0254b1f15fe5b7eefedbca47862605&quot;,
#                 {
#                     center: [30.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5cf7644cbcf7956a1070a8f2880b5f93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5cf7644cbcf7956a1070a8f2880b5f93.addTo(map_6d0254b1f15fe5b7eefedbca47862605);
#
#
#             var marker_10f8c9944ded5b51e6fbe26ad86c273e = L.marker(
#                 [34.60066456792494, -81.84888278152249],
#                 {}
#             ).addTo(map_6d0254b1f15fe5b7eefedbca47862605);
#
#
#             var icon_e445098e444c95b3647915a5c170c288 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_10f8c9944ded5b51e6fbe26ad86c273e.setIcon(icon_e445098e444c95b3647915a5c170c288);
#
#
#         var popup_ae8b4753c73d5d86e4693b6a47a55c02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e6bbc6df96a0c648152a5d11ffcca61 = $(`&lt;div id=&quot;html_3e6bbc6df96a0c648152a5d11ffcca61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_ae8b4753c73d5d86e4693b6a47a55c02.setContent(html_3e6bbc6df96a0c648152a5d11ffcca61);
#
#
#
#         marker_10f8c9944ded5b51e6fbe26ad86c273e.bindPopup(popup_ae8b4753c73d5d86e4693b6a47a55c02)
#         ;
#
#
#
#
#             var marker_218ba86d9fd17203561664da4b749155 = L.marker(
#                 [32.845709324412496, -85.25956231351199],
#                 {}
#             ).addTo(map_6d0254b1f15fe5b7eefedbca47862605);
#
#
#             var icon_85db9b1fd790ea24a4f6ba24db1e794a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_218ba86d9fd17203561664da4b749155.setIcon(icon_85db9b1fd790ea24a4f6ba24db1e794a);
#
#
#         var popup_37d5e7d941ddc70694ca1f7dbf2d42fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2e474947a61b6502d77da32554dd4af = $(`&lt;div id=&quot;html_b2e474947a61b6502d77da32554dd4af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 2&lt;/div&gt;`)[0];
#                 popup_37d5e7d941ddc70694ca1f7dbf2d42fe.setContent(html_b2e474947a61b6502d77da32554dd4af);
#
#
#
#         marker_218ba86d9fd17203561664da4b749155.bindPopup(popup_37d5e7d941ddc70694ca1f7dbf2d42fe)
#         ;
#
#
#
#
#             var marker_cef34d31b4058b283347de7d37c0711d = L.marker(
#                 [38.04217939524085, -90.78076420867686],
#                 {}
#             ).addTo(map_6d0254b1f15fe5b7eefedbca47862605);
#
#
#             var icon_9d1c296ffb5ca68ada5d4e5ec767c28e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cef34d31b4058b283347de7d37c0711d.setIcon(icon_9d1c296ffb5ca68ada5d4e5ec767c28e);
#
#
#         var popup_071af0616d0e79f365f11ba2d1cc4070 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dcf0716fe7258aedfa9c633e24ef72e8 = $(`&lt;div id=&quot;html_dcf0716fe7258aedfa9c633e24ef72e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 3&lt;/div&gt;`)[0];
#                 popup_071af0616d0e79f365f11ba2d1cc4070.setContent(html_dcf0716fe7258aedfa9c633e24ef72e8);
#
#
#
#         marker_cef34d31b4058b283347de7d37c0711d.bindPopup(popup_071af0616d0e79f365f11ba2d1cc4070)
#         ;
#
#
#
#
#             var marker_a6edcfa6b36aa02f1c26d4740ee38e8e = L.marker(
#                 [34.51273673121469, -83.36720445706295],
#                 {}
#             ).addTo(map_6d0254b1f15fe5b7eefedbca47862605);
#
#
#             var icon_6f934353930c6ac40edb1f1491ac665f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconC

# %%
driver_ai.plot_with_connections()
# Out:
# Random points with connections map saved as random_connections_map.html.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebfb4ef4c10044c4b84ac23dc18ca0b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebfb4ef4c10044c4b84ac23dc18ca0b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebfb4ef4c10044c4b84ac23dc18ca0b3 = L.map(
#                 &quot;map_ebfb4ef4c10044c4b84ac23dc18ca0b3&quot;,
#                 {
#                     center: [30.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2df6f7c10b7a2b85eb046e796f49f080 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2df6f7c10b7a2b85eb046e796f49f080.addTo(map_ebfb4ef4c10044c4b84ac23dc18ca0b3);
#
#
#             var marker_612932de887ba2a1d514b6271653ced0 = L.marker(
#                 [34.60066456792494, -81.84888278152249],
#                 {}
#             ).addTo(map_ebfb4ef4c10044c4b84ac23dc18ca0b3);
#
#
#             var icon_1115c6dc97e681b9b014b0ec3796a167 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_612932de887ba2a1d514b6271653ced0.setIcon(icon_1115c6dc97e681b9b014b0ec3796a167);
#
#
#         var popup_1793600676ddd919790390c9b3a1f0b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba8ee193460143d43b36772cdc06747c = $(`&lt;div id=&quot;html_ba8ee193460143d43b36772cdc06747c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_1793600676ddd919790390c9b3a1f0b4.setContent(html_ba8ee193460143d43b36772cdc06747c);
#
#
#
#         marker_612932de887ba2a1d514b6271653ced0.bindPopup(popup_1793600676ddd919790390c9b3a1f0b4)
#         ;
#
#
#
#
#             var marker_aa895ef2b8612c449efc78b4ab5600ff = L.marker(
#                 [32.845709324412496, -85.25956231351199],
#                 {}
#             ).addTo(map_ebfb4ef4c10044c4b84ac23dc18ca0b3);
#
#
#             var icon_2593cad820fb7ef0eeb53c8740e09330 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aa895ef2b8612c449efc78b4ab5600ff.setIcon(icon_2593cad820fb7ef0eeb53c8740e09330);
#
#
#         var popup_fe9a2fa965e9f47852c919c08b331c27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8dc7b069893dc87b13c1656dadaac16e = $(`&lt;div id=&quot;html_8dc7b069893dc87b13c1656dadaac16e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 2&lt;/div&gt;`)[0];
#                 popup_fe9a2fa965e9f47852c919c08b331c27.setContent(html_8dc7b069893dc87b13c1656dadaac16e);
#
#
#
#         marker_aa895ef2b8612c449efc78b4ab5600ff.bindPopup(popup_fe9a2fa965e9f47852c919c08b331c27)
#         ;
#
#
#
#
#             var marker_ab4170185e5b10d4c0bffe47ab929e48 = L.marker(
#                 [38.04217939524085, -90.78076420867686],
#                 {}
#             ).addTo(map_ebfb4ef4c10044c4b84ac23dc18ca0b3);
#
#
#             var icon_6b764e6d83aef2fe0260cd032c50e759 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ab4170185e5b10d4c0bffe47ab929e48.setIcon(icon_6b764e6d83aef2fe0260cd032c50e759);
#
#
#         var popup_79f9b7a6e44c23c3d242b5f423b32fc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b7ef5dd96e3bf446fd15d5ad3b757f4 = $(`&lt;div id=&quot;html_7b7ef5dd96e3bf446fd15d5ad3b757f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 3&lt;/div&gt;`)[0];
#                 popup_79f9b7a6e44c23c3d242b5f423b32fc0.setContent(html_7b7ef5dd96e3bf446fd15d5ad3b757f4);
#
#
#
#         marker_ab4170185e5b10d4c0bffe47ab929e48.bindPopup(popup_79f9b7a6e44c23c3d242b5f423b32fc0)
#         ;
#
#
#
#
#             var marker_02fa98700d7029badb4474cdecc8332f = L.marker(
#                 [34.51273673121469, -83.36720445706295],
#                 {}
#             ).addTo(map_ebfb4ef4c10044c4b84ac23dc18ca0b3);
#
#
#             var icon_2144059e6d49ecf78405f7b27f4c7eb7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconC

# %%
# Initialize the class
optimal_tour = driver_ai.find_shortest_path()
print(f"Elkai Optimized Tour: {optimal_tour}")
driver_ai.display_optimized_route(optimal_tour)
# Out:
# Elkai Optimized Tour: [0, 4, 90, 78, 3, 8, 98, 77, 55, 10, 35, 70, 52, 82, 49, 58, 42, 54, 60, 2, 81, 36, 37, 74, 7, 85, 25, 57, 43, 71, 67, 47, 50, 26, 87, 79, 28, 56, 23, 66, 34, 75, 64, 88, 39, 63, 80, 29, 45, 38, 9, 73, 20, 46, 32, 22, 44, 33, 18, 13, 91, 97, 21, 83, 61, 11, 40, 24, 19, 14, 99, 93, 89, 72, 53, 65, 68, 48, 51, 1, 59, 31, 95, 96, 76, 41, 69, 92, 6, 17, 16, 94, 86, 15, 84, 27, 12, 5, 62, 30, 0]
# Optimized map saved as optimized_map.html.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbcfe295169f63b8e8896e2733b5b5be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbcfe295169f63b8e8896e2733b5b5be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbcfe295169f63b8e8896e2733b5b5be = L.map(
#                 &quot;map_fbcfe295169f63b8e8896e2733b5b5be&quot;,
#                 {
#                     center: [34.60066456792494, -81.84888278152249],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fc450db9c273ca0ea794ded4fde0e18 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2fc450db9c273ca0ea794ded4fde0e18.addTo(map_fbcfe295169f63b8e8896e2733b5b5be);
#
#
#             var poly_line_a122d57eda17d418a0854acbbfdb4b4f = L.polyline(
#                 [[34.60066456792494, -81.84888278152249], [34.18143832076941, -81.71964198372622]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_fbcfe295169f63b8e8896e2733b5b5be);
#
#
#             var poly_line_a93c88a27f1afd4c2f9f11280140f944 = L.polyline(
#                 [[34.18143832076941, -81.71964198372622], [34.317797736685655, -82.08879658108658]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_fbcfe295169f63b8e8896e2733b5b5be);
#
#
#             var poly_line_8ef127615fd7d9051fb5fefcfd35dd0f = L.polyline(
#                 [[34.317797736685655, -82.08879658108658], [34.583076709015394, -83.34300813214327]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_fbcfe295169f63b8e8896e2733b5b5be);
#
#
#             var poly_line_2ec8be21006568c8a8cf70b533e70d01 = L.polyline(
#                 [[34.583076709015394, -83.34300813214327], [34.51273673121469, -83.36720445706295]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_fbcfe295169f63b8e8896e2733b5b5be);
#
#
#             var poly_line_430bc7179cef69879567a41183627333 = L.polyline(
#                 [[34.51273673121469, -83.36720445706295], [36.939623516039966, -83.55640986270487]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_fbcfe295169f63b8e8896e2733b5b5be);
#
#
#             var poly_line_32417d2ecd484b4fa2c1255036c30ecb = L.polyline(
#                 [[36.939623516039966, -83.55640986270487], [36.63209676797196, -82.50677826049376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &
